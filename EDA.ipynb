# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('C:/Users/vidheesha/OneDrive/Desktop/Vidheesha/python datasets/flipkart_headphones_dataset/flipkart_headphones.csv')

# %%
data.head()
# Out:
#                                                title       color  \
# 0  Wings Phantom Pro Gaming TWS with 30 Hrs Playt...       Black
# 1  Boult Audio ProBass Curve Neckband Bluetooth H...        Blue
# 2  Aroma NB120 Tehalka - 28 Hours Playtime Blueto...       Black
# 3  N2B MAGNET Red & k1 Pack of 2 Bluetooth Blueto...       Black
# 4  OnePlus Bullets Wireless Z Bass Edition Blueto...  Bold Black
#
#              type  avg_rating  num_of_ratings  selling_price   MRP  Unnamed: 7
# 0   True Wireless         4.0            1934           2493  5499         NaN
# 1           Black         4.0          333036            799  3499         NaN
# 2      In the Ear         3.9           10398            379  1999         NaN
# 3             Red         3.5           20079            260  1875         NaN
# 4      In the Ear         4.3          437395           1999  2190         NaN

# %%
data.tail()
# Out:
#                                                  title       color  \
# 995  Aroma NB133B Straight Wireless Earbuds Bluetoo...       Black
# 996  PADRAIG Metal Magnetic Wireless Bluetooth Spor...  Multicolor
# 997  ULTADOR i 12 Q2 Neo with Environment Cancellat...       White
# 998  Hitage NBT-6858 Audio ProBass `Neckband Blueto...         Red
# 999  Boult Audio AirBass Xpods TWS Earbuds with 20H...       Black
#
#                type  avg_rating  num_of_ratings  selling_price   MRP  \
# 995   True Wireless         3.8               0            699  2499
# 996      In the Ear         5.0               0            219   999
# 997   True Wireless         3.0               0            749  1899
# 998      In the Ear         3.7               0            521  1699
# 999   True Wireless         4.0               0           1299  4999
#
#      Unnamed: 7
# 995         NaN
# 996         NaN
# 997         NaN
# 998         NaN
# 999         NaN

# %%
data.shape
# Out:
# (1000, 8)

# %%
data.describe()
# Out:
#         avg_rating  num_of_ratings  selling_price           MRP  Unnamed: 7
# count  1000.000000    1.000000e+03    1000.000000   1000.000000         0.0
# mean      3.831000    5.004075e+04     832.875000   2423.043000         NaN
# std       0.467459    1.572297e+05     812.535141   1774.025318         NaN
# min       1.000000    0.000000e+00      88.000000      0.000000         NaN
# 25%       3.600000    1.167500e+02     349.000000   1079.750000         NaN
# 50%       3.900000    1.712000e+03     599.000000   1999.000000         NaN
# 75%       4.000000    1.332700e+04     999.000000   2999.000000         NaN
# max       5.000000    1.299042e+06    7990.000000  16999.000000         NaN

# %%
data.columns
# Out:
# Index(['title', 'color', 'type', 'avg_rating', 'num_of_ratings',
#        'selling_price', 'MRP', 'Unnamed: 7'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# title                0
# color                0
# type                 0
# avg_rating           0
# num_of_ratings       0
# selling_price        0
# MRP                  0
# Unnamed: 7        1000
# dtype: int64

# %%
sns.boxplot(data.num_of_ratings)
# Out:
# C:\Users\vidheesha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='num_of_ratings'>

# %%
sns.distplot(data.num_of_ratings)
# Out:
# C:\Users\vidheesha\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='num_of_ratings', ylabel='Density'>

# %%
mean_value = data['num_of_ratings'].mean()

# %%
data = data.replace(0,mean_value)

# %%
data_new = data.drop(['Unnamed: 7'],axis = 1)

# %%
data_new.head()
# Out:
#                                                title       color  \
# 0  Wings Phantom Pro Gaming TWS with 30 Hrs Playt...       Black
# 1  Boult Audio ProBass Curve Neckband Bluetooth H...        Blue
# 2  Aroma NB120 Tehalka - 28 Hours Playtime Blueto...       Black
# 3  N2B MAGNET Red & k1 Pack of 2 Bluetooth Blueto...       Black
# 4  OnePlus Bullets Wireless Z Bass Edition Blueto...  Bold Black
#
#              type  avg_rating  num_of_ratings  selling_price     MRP
# 0   True Wireless         4.0          1934.0           2493  5499.0
# 1           Black         4.0        333036.0            799  3499.0
# 2      In the Ear         3.9         10398.0            379  1999.0
# 3             Red         3.5         20079.0            260  1875.0
# 4      In the Ear         4.3        437395.0           1999  2190.0

# %%
data_new.tail()
# Out:
#                                                  title       color  \
# 995  Aroma NB133B Straight Wireless Earbuds Bluetoo...       Black
# 996  PADRAIG Metal Magnetic Wireless Bluetooth Spor...  Multicolor
# 997  ULTADOR i 12 Q2 Neo with Environment Cancellat...       White
# 998  Hitage NBT-6858 Audio ProBass `Neckband Blueto...         Red
# 999  Boult Audio AirBass Xpods TWS Earbuds with 20H...       Black
#
#                type  avg_rating  num_of_ratings  selling_price     MRP
# 995   True Wireless         3.8       50040.749            699  2499.0
# 996      In the Ear         5.0       50040.749            219   999.0
# 997   True Wireless         3.0       50040.749            749  1899.0
# 998      In the Ear         3.7       50040.749            521  1699.0
# 999   True Wireless         4.0       50040.749           1299  4999.0

# %%
corelation = data_new.corr()
print(corelation)
# Out:
#                 avg_rating  num_of_ratings  selling_price       MRP
# avg_rating        1.000000        0.199108       0.013916 -0.009080
# num_of_ratings    0.199108        1.000000      -0.041291 -0.018775
# selling_price     0.013916       -0.041291       1.000000  0.231351
# MRP              -0.009080       -0.018775       0.231351  1.000000

# %%
sns.heatmap(corelation, xticklabels = corelation.columns, yticklabels = corelation.columns, annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data_new)

# %%
sns.relplot(x = 'avg_rating', y = 'num_of_ratings', hue = 'type', data = data_new)

# %%
sns.distplot(data_new['avg_rating'],bins=10)
# Out:
# C:\Users\vidheesha\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='avg_rating', ylabel='Density'>

# %%
sns.distplot(data_new['num_of_ratings'],bins=10)
# Out:
# C:\Users\vidheesha\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='num_of_ratings', ylabel='Density'>

# %%
sns.catplot(x='selling_price',kind='box',data=data_new)
